# %%
# Define some simpe function examples

def test(x,y): # Don't forget the semicolon
    z = x*y
    c = 2    #Note that this is not accessable outside of the function
    return z

def test2(x,y):
    z = x*y
    return x, y, z

a, b, c = test2(2,3)   # Syntax for calling a multiple output function
print('test(2,3) =',test(2,3))
print('test2(2,3) =',test2(2,3))
print('a=',a)
# Out:
# test(2,3) = 6
# test2(2,3) = (2, 3, 6)
# a= 2

# %%
# %run Function_Example.py
print(test(2,3))
# Out:
# 6
